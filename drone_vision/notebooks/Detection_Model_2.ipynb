# %%
import numpy
import os
print("Working Directory: " + str(os.path.realpath(os.getcwd() + '../../../')))
# Out:
# Working Directory: /home/spandan/catkin_ws/src/Anti-Anti-Masker

# %%
train_with_mask = '../../assets/Dataset/maskdata/maskdata/train/with_mask/'
train_without_mask = '../../assets/Dataset/maskdata/maskdata/train/without_mask'
test_with_mask = '../../assets/Dataset/maskdata/maskdata/test/with_mask'
test_without_mask = '../../assets/Dataset/maskdata/maskdata/test/without_mask'
print(len(os.listdir(train_with_mask)))
print(len(os.listdir(train_without_mask)))
print(len(os.listdir(test_with_mask)))
print(len(os.listdir(test_without_mask)))
# Out:
# 2827
# 519
# 98
# 234

# %%
#import sys
from PIL import Image
import matplotlib.pyplot as plt

main_dir = train_with_mask
files = os.listdir(main_dir)
# you can change file extension below to read other image types
images_list = [i for i in files if i.endswith('.jpg')] ## output file names only
i = 0
for idx,image in enumerate(images_list):
  if i>5:
    break
  i = i + 1
  print(idx)
  img = Image.open(main_dir + image)
  print(img.size)
  plt.imshow(img)
  #img = img.resize((480, 600))
# Out:
# 0
# (224, 224)
# 1
# (224, 224)
# 2
# (224, 224)
# 3
# (224, 224)
# 4
# (224, 224)
# 5
# (224, 224)

# %%
# !pip3 install keras
# Out:
# Requirement already satisfied: keras in /home/spandan/.local/lib/python3.8/site-packages (2.8.0)

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Model
from tensorflow.keras.layers import Flatten, Conv2D, Dense, Dropout, AveragePooling2D
from keras_preprocessing import image
from keras_preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import MobileNetV2
# from tensorflow.keras.applications import InceptionV3
from sklearn.metrics import classification_report
import numpy as np
import matplotlib.pyplot as plt
#from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
#from tensorflow.keras.preprocessing.image import img_to_array
#from tensorflow.keras.models import load_model
#from tensorflow.keras.layers import Conv2D, MaxPool2D, Input
#from keras.applications import InceptionV3
#from tensorflow.keras.preprocessing.image import img_to_array
#from tensorflow.keras.preprocessing.image import load_img
#from tensorflow.keras.utils import to_categorical
#from sklearn.preprocessing import LabelBinarizer
#from sklearn.model_selection import train_test_split
#from imutils import paths
#import argparse

# %%
INIT_LR = 1e-4
EPOCHS = 20
BS = 32

# %%
train_DIR = '../../assets/Dataset/maskdata/maskdata/train'
test_DIR = '../../assets/Dataset/maskdata/maskdata/test'

# Image_gen = ImageDataGenerator(rescale=1.0/255.0,
#                                horizontal_flip = True,
#                                rotation_range = 50,
#                                width_shift_range = 0.2,
#                                height_shift_range = 0.2,
#                                zoom_range = 0.2,
#                                fill_mode = 'nearest',
#                                validation_split = 0.2)

Image_gen = ImageDataGenerator(rescale=1.0/255.0,width_shift_range = 0.2,height_shift_range = 0.2,zoom_range = 0.2, fill_mode = 'nearest',validation_split = 0.2 )

train_generator = Image_gen.flow_from_directory(train_DIR,color_mode='rgb',
                                                target_size = (224,224),
                                                batch_size = 20,
                                                class_mode = 'categorical',
                                                subset = "training")

val_generator = Image_gen.flow_from_directory(train_DIR,color_mode='rgb',
                                                target_size = (224,224),
                                                batch_size = 20,
                                                class_mode = 'categorical',
                                                subset = "validation")

test_generator = Image_gen.flow_from_directory(test_DIR,color_mode='rgb',
                                                target_size = (224,224),
                                                batch_size = 20,
                                                class_mode = 'categorical',
                                                )

print(train_generator.image_shape)
print(val_generator.image_shape)
print(test_generator.image_shape)
# Out:
# Found 2678 images belonging to 2 classes.
# Found 668 images belonging to 2 classes.
# Found 332 images belonging to 2 classes.
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)

# %%
input = keras.layers.Input(shape=(224,224,3))
baseModel = MobileNetV2(weights="imagenet", include_top=False, input_shape=(224,224,3), input_tensor= input)

headModel = baseModel.output
headModel = AveragePooling2D(pool_size=(7, 7))(headModel)
headModel = Flatten()(headModel)
headModel = Dense(128, activation="relu")(headModel)
headModel = Dropout(0.5)(headModel)
headModel = Dense(2, activation="tanh")(headModel)
model = Model(inputs=baseModel.input, outputs=headModel)

for layer in baseModel.layers:
	layer.trainable = False

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  Conv1 (Conv2D)                 (None, 112, 112, 32  864         ['input_1[0][0]']
#                                 )
#
#  bn_Conv1 (BatchNormalization)  (None, 112, 112, 32  128         ['Conv1[0][0]']
#                                 )
#
#  Conv1_relu (ReLU)              (None, 112, 112, 32  0           ['bn_Conv1[0][0]']
#                                 )
#
#  expanded_conv_depthwise (Depth  (None, 112, 112, 32  288        ['Conv1_relu[0][0]']
#  wiseConv2D)                    )
#
#  expanded_conv_depthwise_BN (Ba  (None, 112, 112, 32  128        ['expanded_conv_depthwise[0][0]']
#  tchNormalization)              )
#
#  expanded_conv_depthwise_relu (  (None, 112, 112, 32  0          ['expanded_conv_depthwise_BN[0][0
#  ReLU)                          )                                ]']
#
#  expanded_conv_project (Conv2D)  (None, 112, 112, 16  512        ['expanded_conv_depthwise_relu[0]
#                                 )                                [0]']
#
#  expanded_conv_project_BN (Batc  (None, 112, 112, 16  64         ['expanded_conv_project[0][0]']
#  hNormalization)                )
#
#  block_1_expand (Conv2D)        (None, 112, 112, 96  1536        ['expanded_conv_project_BN[0][0]'
#                                 )                                ]
#
#  block_1_expand_BN (BatchNormal  (None, 112, 112, 96  384        ['block_1_expand[0][0]']
#  ization)                       )
#
#  block_1_expand_relu (ReLU)     (None, 112, 112, 96  0           ['block_1_expand_BN[0][0]']
#                                 )
#
#  block_1_pad (ZeroPadding2D)    (None, 113, 113, 96  0           ['block_1_expand_relu[0][0]']
#                                 )
#
#  block_1_depthwise (DepthwiseCo  (None, 56, 56, 96)  864         ['block_1_pad[0][0]']
#  nv2D)
#
#  block_1_depthwise_BN (BatchNor  (None, 56, 56, 96)  384         ['block_1_depthwise[0][0]']
#  malization)
#
#  block_1_depthwise_relu (ReLU)  (None, 56, 56, 96)   0           ['block_1_depthwise_BN[0][0]']
#
#  block_1_project (Conv2D)       (None, 56, 56, 24)   2304        ['block_1_depthwise_relu[0][0]']
#
#  block_1_project_BN (BatchNorma  (None, 56, 56, 24)  96          ['block_1_project[0][0]']
#  lization)
#
#  block_2_expand (Conv2D)        (None, 56, 56, 144)  3456        ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNormal  (None, 56, 56, 144)  576        ['block_2_expand[0][0]']
#  ization)
#
#  block_2_expand_relu (ReLU)     (None, 56, 56, 144)  0           ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (DepthwiseCo  (None, 56, 56, 144)  1296       ['block_2_expand_relu[0][0]']
#  nv2D)
#
#  block_2_depthwise_BN (BatchNor  (None, 56, 56, 144)  576        ['block_2_depthwise[0][0]']
#  malization)
#
#  block_2_depthwise_relu (ReLU)  (None, 56, 56, 144)  0           ['block_2_depthwise_BN[0][0]']
#
#  block_2_project (Conv2D)       (None, 56, 56, 24)   3456        ['block_2_depthwise_relu[0][0]']
#
#  block_2_project_BN (BatchNorma  (None, 56, 56, 24)  96          ['block_2_project[0][0]']
#  lization)
#
#  block_2_add (Add)              (None, 56, 56, 24)   0           ['block_1_project_BN[0][0]',
#                                                                   'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, 56, 56, 144)  3456        ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNormal  (None, 56, 56, 144)  576        ['block_3_expand[0][0]']
#  ization)
#
#  block_3_expand_relu (ReLU)     (None, 56, 56, 144)  0           ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D)    (None, 57, 57, 144)  0           ['block_3_expand_relu[0][0]']
#
#  block_3_depthwise (DepthwiseCo  (None, 28, 28, 144)  1296       ['block_3_pad[0][0]']
#  nv2D)
#
#  block_3_depthwise_BN (BatchNor  (None, 28, 28, 144)  576        ['block_3_depthwise[0][0]']
#  malization)
#
#  block_3_depthwise_relu (ReLU)  (None, 28, 28, 144)  0           ['block_3_depthwise_BN[0][0]']
#
#  block_3_project (Conv2D)       (None, 28, 28, 32)   4608        ['block_3_depthwise_relu[0][0]']
#
#  block_3_project_BN (BatchNorma  (None, 28, 28, 32)  128         ['block_3_project[0][0]']
#  lization)
#
#  block_4_expand (Conv2D)        (None, 28, 28, 192)  6144        ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNormal  (None, 28, 28, 192)  768        ['block_4_expand[0][0]']
#  ization)
#
#  block_4_expand_relu (ReLU)     (None, 28, 28, 192)  0           ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (DepthwiseCo  (None, 28, 28, 192)  1728       ['block_4_expand_relu[0][0]']
#  nv2D)
#
#  block_4_depthwise_BN (BatchNor  (None, 28, 28, 192)  768        ['block_4_depthwise[0][0]']
#  malization)
#
#  block_4_depthwise_relu (ReLU)  (None, 28, 28, 192)  0           ['block_4_depthwise_BN[0][0]']
#
#  block_4_project (Conv2D)       (None, 28, 28, 32)   6144        ['block_4_depthwise_relu[0][0]']
#
#  block_4_project_BN (BatchNorma  (None, 28, 28, 32)  128         ['block_4_project[0][0]']
#  lization)
#
#  block_4_add (Add)              (None, 28, 28, 32)   0           ['block_3_project_BN[0][0]',
#                                                                   'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, 28, 28, 192)  6144        ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNormal  (None, 28, 28, 192)  768        ['block_5_expand[0][0]']
#  ization)
#
#  block_5_expand_relu (ReLU)     (None, 28, 28, 192)  0           ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (DepthwiseCo  (None, 28, 28, 192)  1728       ['block_5_expand_relu[0][0]']
#  nv2D)
#
#  block_5_depthwise_BN (BatchNor  (None, 28, 28, 192)  768        ['block_5_depthwise[0][0]']
#  malization)
#
#  block_5_depthwise_relu (ReLU)  (None, 28, 28, 192)  0           ['block_5_depthwise_BN[0][0]']
#
#  block_5_project (Conv2D)       (None, 28, 28, 32)   6144        ['block_5_depthwise_relu[0][0]']
#
#  block_5_project_BN (BatchNorma  (None, 28, 28, 32)  128         ['block_5_project[0][0]']
#  lization)
#
#  block_5_add (Add)              (None, 28, 28, 32)   0           ['block_4_add[0][0]',
#                                                                   'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, 28, 28, 192)  6144        ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNormal  (None, 28, 28, 192)  768        ['block_6_expand[0][0]']
#  ization)
#
#  block_6_expand_relu (ReLU)     (None, 28, 28, 192)  0           ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D)    (None, 29, 29, 192)  0           ['block_6_expand_relu[0][0]']
#
#  block_6_depthwise (DepthwiseCo  (None, 14, 14, 192)  1728       ['block_6_pad[0][0]']
#  nv2D)
#
#  block_6_depthwise_BN (BatchNor  (None, 14, 14, 192)  768        ['block_6_depthwise[0][0]']
#  malization)
#
#  block_6_depthwise_relu (ReLU)  (None, 14, 14, 192)  0           ['block_6_depthwise_BN[0][0]']
#
#  block_6_project (Conv2D)       (None, 14, 14, 64)   12288       ['block_6_depthwise_relu[0][0]']
#
#  block_6_project_BN (BatchNorma  (None, 14, 14, 64)  256         ['block_6_project[0][0]']
#  lization)
#
#  block_7_expand (Conv2D)        (None, 14, 14, 384)  24576       ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNormal  (None, 14, 14, 384)  1536       ['block_7_expand[0][0]']
#  ization)
#
#  block_7_expand_relu (ReLU)     (None, 14, 14, 384)  0           ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (DepthwiseCo  (None, 14, 14, 384)  3456       ['block_7_expand_relu[0][0]']
#  nv2D)
#
#  block_7_depthwise_BN (BatchNor  (None, 14, 14, 384)  1536       ['block_7_depthwise[0][0]']
#  malization)
#
#  block_7_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           ['block_7_depthwise_BN[0][0]']
#
#  block_7_project (Conv2D)       (None, 14, 14, 64)   24576       ['block_7_depthwise_relu[0][0]']
#
#  block_7_project_BN (BatchNorma  (None, 14, 14, 64)  256         ['block_7_project[0][0]']
#  lization)
#
#  block_7_add (Add)              (None, 14, 14, 64)   0           ['block_6_project_BN[0][0]',
#                                                                   'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, 14, 14, 384)  24576       ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNormal  (None, 14, 14, 384)  1536       ['block_8_expand[0][0]']
#  ization)
#
#  block_8_expand_relu (ReLU)     (None, 14, 14, 384)  0           ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (DepthwiseCo  (None, 14, 14, 384)  3456       ['block_8_expand_relu[0][0]']
#  nv2D)
#
#  block_8_depthwise_BN (BatchNor  (None, 14, 14, 384)  1536       ['block_8_depthwise[0][0]']
#  malization)
#
#  block_8_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           ['block_8_depthwise_BN[0][0]']
#
#  block_8_project (Conv2D)       (None, 14, 14, 64)   24576       ['block_8_depthwise_relu[0][0]']
#
#  block_8_project_BN (BatchNorma  (None, 14, 14, 64)  256         ['block_8_project[0][0]']
#  lization)
#
#  block_8_add (Add)              (None, 14, 14, 64)   0           ['block_7_add[0][0]',
#                                                                   'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)        (None, 14, 14, 384)  24576       ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNormal  (None, 14, 14, 384)  1536       ['block_9_expand[0][0]']
#  ization)
#
#  block_9_expand_relu (ReLU)     (None, 14, 14, 384)  0           ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (DepthwiseCo  (None, 14, 14, 384)  3456       ['block_9_expand_relu[0][0]']
#  nv2D)
#
#  block_9_depthwise_BN (BatchNor  (None, 14, 14, 384)  1536       ['block_9_depthwise[0][0]']
#  malization)
#
#  block_9_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           ['block_9_depthwise_BN[0][0]']
#
#  block_9_project (Conv2D)       (None, 14, 14, 64)   24576       ['block_9_depthwise_relu[0][0]']
#
#  block_9_project_BN (BatchNorma  (None, 14, 14, 64)  256         ['block_9_project[0][0]']
#  lization)
#
#  block_9_add (Add)              (None, 14, 14, 64)   0           ['block_8_add[0][0]',
#                                                                   'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, 14, 14, 384)  24576       ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchNorma  (None, 14, 14, 384)  1536       ['block_10_expand[0][0]']
#  lization)
#
#  block_10_expand_relu (ReLU)    (None, 14, 14, 384)  0           ['block_10_expand_BN[0][0]']
#
#  block_10_depthwise (DepthwiseC  (None, 14, 14, 384)  3456       ['block_10_expand_relu[0][0]']
#  onv2D)
#
#  block_10_depthwise_BN (BatchNo  (None, 14, 14, 384)  1536       ['block_10_depthwise[0][0]']
#  rmalization)
#
#  block_10_depthwise_relu (ReLU)  (None, 14, 14, 384)  0          ['block_10_depthwise_BN[0][0]']
#
#  block_10_project (Conv2D)      (None, 14, 14, 96)   36864       ['block_10_depthwise_relu[0][0]']
#
#  block_10_project_BN (BatchNorm  (None, 14, 14, 96)  384         ['block_10_project[0][0]']
#  alization)
#
#  block_11_expand (Conv2D)       (None, 14, 14, 576)  55296       ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchNorma  (None, 14, 14, 576)  2304       ['block_11_expand[0][0]']
#  lization)
#
#  block_11_expand_relu (ReLU)    (None, 14, 14, 576)  0           ['block_11_expand_BN[0][0]']
#
#  block_11_depthwise (DepthwiseC  (None, 14, 14, 576)  5184       ['block_11_expand_relu[0][0]']
#  onv2D)
#
#  block_11_depthwise_BN (BatchNo  (None, 14, 14, 576)  2304       ['block_11_depthwise[0][0]']
#  rmalization)
#
#  block_11_depthwise_relu (ReLU)  (None, 14, 14, 576)  0          ['block_11_depthwise_BN[0][0]']
#
#  block_11_project (Conv2D)      (None, 14, 14, 96)   55296       ['block_11_depthwise_relu[0][0]']
#
#  block_11_project_BN (BatchNorm  (None, 14, 14, 96)  384         ['block_11_project[0][0]']
#  alization)
#
#  block_11_add (Add)             (None, 14, 14, 96)   0           ['block_10_project_BN[0][0]',
#                                                                   'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, 14, 14, 576)  55296       ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchNorma  (None, 14, 14, 576)  2304       ['block_12_expand[0][0]']
#  lization)
#
#  block_12_expand_relu (ReLU)    (None, 14, 14, 576)  0           ['block_12_expand_BN[0][0]']
#
#  block_12_depthwise (DepthwiseC  (None, 14, 14, 576)  5184       ['block_12_expand_relu[0][0]']
#  onv2D)
#
#  block_12_depthwise_BN (BatchNo  (None, 14, 14, 576)  2304       ['block_12_depthwise[0][0]']
#  rmalization)
#
#  block_12_depthwise_relu (ReLU)  (None, 14, 14, 576)  0          ['block_12_depthwise_BN[0][0]']
#
#  block_12_project (Conv2D)      (None, 14, 14, 96)   55296       ['block_12_depthwise_relu[0][0]']
#
#  block_12_project_BN (BatchNorm  (None, 14, 14, 96)  384         ['block_12_project[0][0]']
#  alization)
#
#  block_12_add (Add)             (None, 14, 14, 96)   0           ['block_11_add[0][0]',
#                                                                   'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, 14, 14, 576)  55296       ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchNorma  (None, 14, 14, 576)  2304       ['block_13_expand[0][0]']
#  lization)
#
#  block_13_expand_relu (ReLU)    (None, 14, 14, 576)  0           ['block_13_expand_BN[0][0]']
#
#  block_13_pad (ZeroPadding2D)   (None, 15, 15, 576)  0           ['block_13_expand_relu[0][0]']
#
#  block_13_depthwise (DepthwiseC  (None, 7, 7, 576)   5184        ['block_13_pad[0][0]']
#  onv2D)
#
#  block_13_depthwise_BN (BatchNo  (None, 7, 7, 576)   2304        ['block_13_depthwise[0][0]']
#  rmalization)
#
#  block_13_depthwise_relu (ReLU)  (None, 7, 7, 576)   0           ['block_13_depthwise_BN[0][0]']
#
#  block_13_project (Conv2D)      (None, 7, 7, 160)    92160       ['block_13_depthwise_relu[0][0]']
#
#  block_13_project_BN (BatchNorm  (None, 7, 7, 160)   640         ['block_13_project[0][0]']
#  alization)
#
#  block_14_expand (Conv2D)       (None, 7, 7, 960)    153600      ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchNorma  (None, 7, 7, 960)   3840        ['block_14_expand[0][0]']
#  lization)
#
#  block_14_expand_relu (ReLU)    (None, 7, 7, 960)    0           ['block_14_expand_BN[0][0]']
#
#  block_14_depthwise (DepthwiseC  (None, 7, 7, 960)   8640        ['block_14_expand_relu[0][0]']
#  onv2D)
#
#  block_14_depthwise_BN (BatchNo  (None, 7, 7, 960)   3840        ['block_14_depthwise[0][0]']
#  rmalization)
#
#  block_14_depthwise_relu (ReLU)  (None, 7, 7, 960)   0           ['block_14_depthwise_BN[0][0]']
#
#  block_14_project (Conv2D)      (None, 7, 7, 160)    153600      ['block_14_depthwise_relu[0][0]']
#
#  block_14_project_BN (BatchNorm  (None, 7, 7, 160)   640         ['block_14_project[0][0]']
#  alization)
#
#  block_14_add (Add)             (None, 7, 7, 160)    0           ['block_13_project_BN[0][0]',
#                                                                   'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)       (None, 7, 7, 960)    153600      ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchNorma  (None, 7, 7, 960)   3840        ['block_15_expand[0][0]']
#  lization)
#
#  block_15_expand_relu (ReLU)    (None, 7, 7, 960)    0           ['block_15_expand_BN[0][0]']
#
#  block_15_depthwise (DepthwiseC  (None, 7, 7, 960)   8640        ['block_15_expand_relu[0][0]']
#  onv2D)
#
#  block_15_depthwise_BN (BatchNo  (None, 7, 7, 960)   3840        ['block_15_depthwise[0][0]']
#  rmalization)
#
#  block_15_depthwise_relu (ReLU)  (None, 7, 7, 960)   0           ['block_15_depthwise_BN[0][0]']
#
#  block_15_project (Conv2D)      (None, 7, 7, 160)    153600      ['block_15_depthwise_relu[0][0]']
#
#  block_15_project_BN (BatchNorm  (None, 7, 7, 160)   640         ['block_15_project[0][0]']
#  alization)
#
#  block_15_add (Add)             (None, 7, 7, 160)    0           ['block_14_add[0][0]',
#                                                                   'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)       (None, 7, 7, 960)    153600      ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchNorma  (None, 7, 7, 960)   3840        ['block_16_expand[0][0]']
#  lization)
#
#  block_16_expand_relu (ReLU)    (None, 7, 7, 960)    0           ['block_16_expand_BN[0][0]']
#
#  block_16_depthwise (DepthwiseC  (None, 7, 7, 960)   8640        ['block_16_expand_relu[0][0]']
#  onv2D)
#
#  block_16_depthwise_BN (BatchNo  (None, 7, 7, 960)   3840        ['block_16_depthwise[0][0]']
#  rmalization)
#
#  block_16_depthwise_relu (ReLU)  (None, 7, 7, 960)   0           ['block_16_depthwise_BN[0][0]']
#
#  block_16_project (Conv2D)      (None, 7, 7, 320)    307200      ['block_16_depthwise_relu[0][0]']
#
#  block_16_project_BN (BatchNorm  (None, 7, 7, 320)   1280        ['block_16_project[0][0]']
#  alization)
#
#  Conv_1 (Conv2D)                (None, 7, 7, 1280)   409600      ['block_16_project_BN[0][0]']
#
#  Conv_1_bn (BatchNormalization)  (None, 7, 7, 1280)  5120        ['Conv_1[0][0]']
#
#  out_relu (ReLU)                (None, 7, 7, 1280)   0           ['Conv_1_bn[0][0]']
#
#  average_pooling2d (AveragePool  (None, 1, 1, 1280)  0           ['out_relu[0][0]']
#  ing2D)
#
#  flatten (Flatten)              (None, 1280)         0           ['average_pooling2d[0][0]']
#
#  dense (Dense)                  (None, 128)          163968      ['flatten[0][0]']
#
#  dropout (Dropout)              (None, 128)          0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 2)            258         ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 2,422,210
# Trainable params: 164,226
# Non-trainable params: 2,257,984
# __________________________________________________________________________________________________

# %%
print("[INFO] compiling model...")
opt = Adam(learning_rate=INIT_LR, decay=INIT_LR / EPOCHS)
model.compile(loss="binary_crossentropy", optimizer=opt,
	metrics=["accuracy"])
# train the head of the network
print("[INFO] training head...")
H = model.fit(train_generator, batch_size=BS, validation_data=val_generator, epochs=EPOCHS,verbose = 2)
# Out:
# [INFO] compiling model...
# [INFO] training head...
# Epoch 1/20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_11040/2587647116.py in <module>
#       5 # train the head of the network
#       6 print("[INFO] training head...")
# ----> 7 H = model.fit(train_generator, batch_size=BS, validation_data=val_generator, epochs=EPOCHS,verbose = 2)
#
# ~/.local/lib/python3.8/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/.local/lib/python3.8/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1382                 _r=1):
#    1383               callbacks.on_train_batch_begin(step)
# -> 1384               tmp_logs = self.train_function(iterator)
#    1385               if data_handler.should_sync:
#    1386                 context.async_wait()
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2954       (graph_function,
#    2955        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2956     return graph_function._call_flat(
#    2957         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2958
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1851         and executing_eagerly):
#    1852       # No tape is watching; skip to running the function.
# -> 1853       return self._build_call_outputs(self._inference_function.call(
#    1854           ctx, args, cancellation_manager=cancellation_manager))
#    1855     forward_backward = self._select_forward_and_backward_functions(
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     497       with _InterpolateFunctionError(self):
#     498         if cancellation_manager is None:
# --> 499           outputs = execute.execute(
#     500               str(self.signature.name),
#     501               num_outputs=self._num_outputs,
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
model.evaluate(test_generator,batch_size= BS, verbose=2)
# Out:
# 17/17 - 9s - loss: 0.0517 - accuracy: 0.9849 - 9s/epoch - 528ms/step
# [0.05170046165585518, 0.9849397540092468]

# %%
print("[INFO] evaluating network...")
predIdxs = model.predict(test_generator, batch_size=BS,verbose=2, )

predIdxs = np.argmax(predIdxs, axis=1)
# Out:
# [INFO] evaluating network...
# 17/17 - 8s - 8s/epoch - 488ms/step

# %%
test_labels=test_generator.classes 
print(classification_report(test_labels, predIdxs))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.28      0.30      0.29        98
#            1       0.70      0.69      0.69       234
#
#     accuracy                           0.57       332
#    macro avg       0.49      0.49      0.49       332
# weighted avg       0.58      0.57      0.57       332

# %%
# model.save("../saved_model", save_format="h5")

# %%
N = EPOCHS
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), H.history["val_accuracy"], label="val_acc")
plt.plot(np.arange(0, N), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")

# %%
k = "../../assets/test_photos/7.jpg"
import cv2
from keras_preprocessing import image
images = image.load_img(k, target_size=(224, 224))
x1 = image.img_to_array(images)
#x1 = image.rgb_to_grayscale(x1)
x = np.expand_dims(x1, axis=0)
x = x/255.0
plt.imshow(images)
plt.grid(None)
k = model.predict(x)
print("Mask: ",k[0][0])
print("Non Mask: ",k[0][1])
# Out:
# Mask:  0.98940647
# Non Mask:  0.036752433

# %%
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2
full_model = tf.function(lambda x: model(x))
full_model = full_model.get_concrete_function(
    tf.TensorSpec(model.inputs[0].shape, model.inputs[0].dtype, name="yourInputName"))
# Get frozen ConcreteFunction
frozen_func = convert_variables_to_constants_v2(full_model)
frozen_func.graph.as_graph_def()
layers = [op.name for op in frozen_func.graph.get_operations()]
print("-" * 50)
print("Frozen model layers: ")
for layer in layers:
    print(layer)
print("-" * 50)
print("Frozen model inputs: ")
print(frozen_func.inputs)
print("Frozen model outputs: ")
print(frozen_func.outputs)
# Save frozen graph from frozen ConcreteFunction to hard drive
tf.io.write_graph(graph_or_graph_def=frozen_func.graph,
                  logdir="../frozen_models",
                  name="frozen_graph.pb",
                  as_text=False)
# Out:
# --------------------------------------------------
# Frozen model layers:
# yourInputName
# model/Conv1/Conv2D/ReadVariableOp/resource
# model/Conv1/Conv2D/ReadVariableOp
# model/Conv1/Conv2D
# model/bn_Conv1/ReadVariableOp/resource
# model/bn_Conv1/ReadVariableOp
# model/bn_Conv1/ReadVariableOp_1/resource
# model/bn_Conv1/ReadVariableOp_1
# model/bn_Conv1/FusedBatchNormV3/ReadVariableOp/resource
# model/bn_Conv1/FusedBatchNormV3/ReadVariableOp
# model/bn_Conv1/FusedBatchNormV3/ReadVariableOp_1/resource
# model/bn_Conv1/FusedBatchNormV3/ReadVariableOp_1
# model/bn_Conv1/FusedBatchNormV3
# model/Conv1_relu/Relu6
# model/expanded_conv_depthwise/depthwise/ReadVariableOp/resource
# model/expanded_conv_depthwise/depthwise/ReadVariableOp
# model/expanded_conv_depthwise/depthwise
# model/expanded_conv_depthwise_BN/ReadVariableOp/resource
# model/expanded_conv_depthwise_BN/ReadVariableOp
# model/expanded_conv_depthwise_BN/ReadVariableOp_1/resource
# model/expanded_conv_depthwise_BN/ReadVariableOp_1
# model/expanded_conv_depthwise_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/expanded_conv_depthwise_BN/FusedBatchNormV3/ReadVariableOp
# model/expanded_conv_depthwise_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/expanded_conv_depthwise_BN/FusedBatchNormV3/ReadVariableOp_1
# model/expanded_conv_depthwise_BN/FusedBatchNormV3
# model/expanded_conv_depthwise_relu/Relu6
# model/expanded_conv_project/Conv2D/ReadVariableOp/resource
# model/expanded_conv_project/Conv2D/ReadVariableOp
# model/expanded_conv_project/Conv2D
# model/expanded_conv_project_BN/ReadVariableOp/resource
# model/expanded_conv_project_BN/ReadVariableOp
# model/expanded_conv_project_BN/ReadVariableOp_1/resource
# model/expanded_conv_project_BN/ReadVariableOp_1
# model/expanded_conv_project_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/expanded_conv_project_BN/FusedBatchNormV3/ReadVariableOp
# model/expanded_conv_project_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/expanded_conv_project_BN/FusedBatchNormV3/ReadVariableOp_1
# model/expanded_conv_project_BN/FusedBatchNormV3
# model/block_1_expand/Conv2D/ReadVariableOp/resource
# model/block_1_expand/Conv2D/ReadVariableOp
# model/block_1_expand/Conv2D
# model/block_1_expand_BN/ReadVariableOp/resource
# model/block_1_expand_BN/ReadVariableOp
# model/block_1_expand_BN/ReadVariableOp_1/resource
# model/block_1_expand_BN/ReadVariableOp_1
# model/block_1_expand_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_1_expand_BN/FusedBatchNormV3/ReadVariableOp
# model/block_1_expand_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_1_expand_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_1_expand_BN/FusedBatchNormV3
# model/block_1_expand_relu/Relu6
# model/block_1_pad/Pad/paddings
# model/block_1_pad/Pad
# model/block_1_depthwise/depthwise/ReadVariableOp/resource
# model/block_1_depthwise/depthwise/ReadVariableOp
# model/block_1_depthwise/depthwise
# model/block_1_depthwise_BN/ReadVariableOp/resource
# model/block_1_depthwise_BN/ReadVariableOp
# model/block_1_depthwise_BN/ReadVariableOp_1/resource
# model/block_1_depthwise_BN/ReadVariableOp_1
# model/block_1_depthwise_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_1_depthwise_BN/FusedBatchNormV3/ReadVariableOp
# model/block_1_depthwise_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_1_depthwise_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_1_depthwise_BN/FusedBatchNormV3
# model/block_1_depthwise_relu/Relu6
# model/block_1_project/Conv2D/ReadVariableOp/resource
# model/block_1_project/Conv2D/ReadVariableOp
# model/block_1_project/Conv2D
# model/block_1_project_BN/ReadVariableOp/resource
# model/block_1_project_BN/ReadVariableOp
# model/block_1_project_BN/ReadVariableOp_1/resource
# model/block_1_project_BN/ReadVariableOp_1
# model/block_1_project_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_1_project_BN/FusedBatchNormV3/ReadVariableOp
# model/block_1_project_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_1_project_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_1_project_BN/FusedBatchNormV3
# model/block_2_expand/Conv2D/ReadVariableOp/resource
# model/block_2_expand/Conv2D/ReadVariableOp
# model/block_2_expand/Conv2D
# model/block_2_expand_BN/ReadVariableOp/resource
# model/block_2_expand_BN/ReadVariableOp
# model/block_2_expand_BN/ReadVariableOp_1/resource
# model/block_2_expand_BN/ReadVariableOp_1
# model/block_2_expand_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_2_expand_BN/FusedBatchNormV3/ReadVariableOp
# model/block_2_expand_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_2_expand_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_2_expand_BN/FusedBatchNormV3
# model/block_2_expand_relu/Relu6
# model/block_2_depthwise/depthwise/ReadVariableOp/resource
# model/block_2_depthwise/depthwise/ReadVariableOp
# model/block_2_depthwise/depthwise
# model/block_2_depthwise_BN/ReadVariableOp/resource
# model/block_2_depthwise_BN/ReadVariableOp
# model/block_2_depthwise_BN/ReadVariableOp_1/resource
# model/block_2_depthwise_BN/ReadVariableOp_1
# model/block_2_depthwise_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_2_depthwise_BN/FusedBatchNormV3/ReadVariableOp
# model/block_2_depthwise_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_2_depthwise_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_2_depthwise_BN/FusedBatchNormV3
# model/block_2_depthwise_relu/Relu6
# model/block_2_project/Conv2D/ReadVariableOp/resource
# model/block_2_project/Conv2D/ReadVariableOp
# model/block_2_project/Conv2D
# model/block_2_project_BN/ReadVariableOp/resource
# model/block_2_project_BN/ReadVariableOp
# model/block_2_project_BN/ReadVariableOp_1/resource
# model/block_2_project_BN/ReadVariableOp_1
# model/block_2_project_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_2_project_BN/FusedBatchNormV3/ReadVariableOp
# model/block_2_project_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_2_project_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_2_project_BN/FusedBatchNormV3
# model/block_2_add/add
# model/block_3_expand/Conv2D/ReadVariableOp/resource
# model/block_3_expand/Conv2D/ReadVariableOp
# model/block_3_expand/Conv2D
# model/block_3_expand_BN/ReadVariableOp/resource
# model/block_3_expand_BN/ReadVariableOp
# model/block_3_expand_BN/ReadVariableOp_1/resource
# model/block_3_expand_BN/ReadVariableOp_1
# model/block_3_expand_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_3_expand_BN/FusedBatchNormV3/ReadVariableOp
# model/block_3_expand_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_3_expand_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_3_expand_BN/FusedBatchNormV3
# model/block_3_expand_relu/Relu6
# model/block_3_pad/Pad/paddings
# model/block_3_pad/Pad
# model/block_3_depthwise/depthwise/ReadVariableOp/resource
# model/block_3_depthwise/depthwise/ReadVariableOp
# model/block_3_depthwise/depthwise
# model/block_3_depthwise_BN/ReadVariableOp/resource
# model/block_3_depthwise_BN/ReadVariableOp
# model/block_3_depthwise_BN/ReadVariableOp_1/resource
# model/block_3_depthwise_BN/ReadVariableOp_1
# model/block_3_depthwise_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_3_depthwise_BN/FusedBatchNormV3/ReadVariableOp
# model/block_3_depthwise_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_3_depthwise_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_3_depthwise_BN/FusedBatchNormV3
# model/block_3_depthwise_relu/Relu6
# model/block_3_project/Conv2D/ReadVariableOp/resource
# model/block_3_project/Conv2D/ReadVariableOp
# model/block_3_project/Conv2D
# model/block_3_project_BN/ReadVariableOp/resource
# model/block_3_project_BN/ReadVariableOp
# model/block_3_project_BN/ReadVariableOp_1/resource
# model/block_3_project_BN/ReadVariableOp_1
# model/block_3_project_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_3_project_BN/FusedBatchNormV3/ReadVariableOp
# model/block_3_project_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_3_project_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_3_project_BN/FusedBatchNormV3
# model/block_4_expand/Conv2D/ReadVariableOp/resource
# model/block_4_expand/Conv2D/ReadVariableOp
# model/block_4_expand/Conv2D
# model/block_4_expand_BN/ReadVariableOp/resource
# model/block_4_expand_BN/ReadVariableOp
# model/block_4_expand_BN/ReadVariableOp_1/resource
# model/block_4_expand_BN/ReadVariableOp_1
# model/block_4_expand_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_4_expand_BN/FusedBatchNormV3/ReadVariableOp
# model/block_4_expand_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_4_expand_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_4_expand_BN/FusedBatchNormV3
# model/block_4_expand_relu/Relu6
# model/block_4_depthwise/depthwise/ReadVariableOp/resource
# model/block_4_depthwise/depthwise/ReadVariableOp
# model/block_4_depthwise/depthwise
# model/block_4_depthwise_BN/ReadVariableOp/resource
# model/block_4_depthwise_BN/ReadVariableOp
# model/block_4_depthwise_BN/ReadVariableOp_1/resource
# model/block_4_depthwise_BN/ReadVariableOp_1
# model/block_4_depthwise_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_4_depthwise_BN/FusedBatchNormV3/ReadVariableOp
# model/block_4_depthwise_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_4_depthwise_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_4_depthwise_BN/FusedBatchNormV3
# model/block_4_depthwise_relu/Relu6
# model/block_4_project/Conv2D/ReadVariableOp/resource
# model/block_4_project/Conv2D/ReadVariableOp
# model/block_4_project/Conv2D
# model/block_4_project_BN/ReadVariableOp/resource
# model/block_4_project_BN/ReadVariableOp
# model/block_4_project_BN/ReadVariableOp_1/resource
# model/block_4_project_BN/ReadVariableOp_1
# model/block_4_project_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_4_project_BN/FusedBatchNormV3/ReadVariableOp
# model/block_4_project_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_4_project_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_4_project_BN/FusedBatchNormV3
# model/block_4_add/add
# model/block_5_expand/Conv2D/ReadVariableOp/resource
# model/block_5_expand/Conv2D/ReadVariableOp
# model/block_5_expand/Conv2D
# model/block_5_expand_BN/ReadVariableOp/resource
# model/block_5_expand_BN/ReadVariableOp
# model/block_5_expand_BN/ReadVariableOp_1/resource
# model/block_5_expand_BN/ReadVariableOp_1
# model/block_5_expand_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_5_expand_BN/FusedBatchNormV3/ReadVariableOp
# model/block_5_expand_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_5_expand_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_5_expand_BN/FusedBatchNormV3
# model/block_5_expand_relu/Relu6
# model/block_5_depthwise/depthwise/ReadVariableOp/resource
# model/block_5_depthwise/depthwise/ReadVariableOp
# model/block_5_depthwise/depthwise
# model/block_5_depthwise_BN/ReadVariableOp/resource
# model/block_5_depthwise_BN/ReadVariableOp
# model/block_5_depthwise_BN/ReadVariableOp_1/resource
# model/block_5_depthwise_BN/ReadVariableOp_1
# model/block_5_depthwise_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_5_depthwise_BN/FusedBatchNormV3/ReadVariableOp
# model/block_5_depthwise_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_5_depthwise_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_5_depthwise_BN/FusedBatchNormV3
# model/block_5_depthwise_relu/Relu6
# model/block_5_project/Conv2D/ReadVariableOp/resource
# model/block_5_project/Conv2D/ReadVariableOp
# model/block_5_project/Conv2D
# model/block_5_project_BN/ReadVariableOp/resource
# model/block_5_project_BN/ReadVariableOp
# model/block_5_project_BN/ReadVariableOp_1/resource
# model/block_5_project_BN/ReadVariableOp_1
# model/block_5_project_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_5_project_BN/FusedBatchNormV3/ReadVariableOp
# model/block_5_project_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_5_project_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_5_project_BN/FusedBatchNormV3
# model/block_5_add/add
# model/block_6_expand/Conv2D/ReadVariableOp/resource
# model/block_6_expand/Conv2D/ReadVariableOp
# model/block_6_expand/Conv2D
# model/block_6_expand_BN/ReadVariableOp/resource
# model/block_6_expand_BN/ReadVariableOp
# model/block_6_expand_BN/ReadVariableOp_1/resource
# model/block_6_expand_BN/ReadVariableOp_1
# model/block_6_expand_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_6_expand_BN/FusedBatchNormV3/ReadVariableOp
# model/block_6_expand_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_6_expand_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_6_expand_BN/FusedBatchNormV3
# model/block_6_expand_relu/Relu6
# model/block_6_pad/Pad/paddings
# model/block_6_pad/Pad
# model/block_6_depthwise/depthwise/ReadVariableOp/resource
# model/block_6_depthwise/depthwise/ReadVariableOp
# model/block_6_depthwise/depthwise
# model/block_6_depthwise_BN/ReadVariableOp/resource
# model/block_6_depthwise_BN/ReadVariableOp
# model/block_6_depthwise_BN/ReadVariableOp_1/resource
# model/block_6_depthwise_BN/ReadVariableOp_1
# model/block_6_depthwise_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_6_depthwise_BN/FusedBatchNormV3/ReadVariableOp
# model/block_6_depthwise_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_6_depthwise_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_6_depthwise_BN/FusedBatchNormV3
# model/block_6_depthwise_relu/Relu6
# model/block_6_project/Conv2D/ReadVariableOp/resource
# model/block_6_project/Conv2D/ReadVariableOp
# model/block_6_project/Conv2D
# model/block_6_project_BN/ReadVariableOp/resource
# model/block_6_project_BN/ReadVariableOp
# model/block_6_project_BN/ReadVariableOp_1/resource
# model/block_6_project_BN/ReadVariableOp_1
# model/block_6_project_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_6_project_BN/FusedBatchNormV3/ReadVariableOp
# model/block_6_project_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_6_project_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_6_project_BN/FusedBatchNormV3
# model/block_7_expand/Conv2D/ReadVariableOp/resource
# model/block_7_expand/Conv2D/ReadVariableOp
# model/block_7_expand/Conv2D
# model/block_7_expand_BN/ReadVariableOp/resource
# model/block_7_expand_BN/ReadVariableOp
# model/block_7_expand_BN/ReadVariableOp_1/resource
# model/block_7_expand_BN/ReadVariableOp_1
# model/block_7_expand_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_7_expand_BN/FusedBatchNormV3/ReadVariableOp
# model/block_7_expand_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_7_expand_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_7_expand_BN/FusedBatchNormV3
# model/block_7_expand_relu/Relu6
# model/block_7_depthwise/depthwise/ReadVariableOp/resource
# model/block_7_depthwise/depthwise/ReadVariableOp
# model/block_7_depthwise/depthwise
# model/block_7_depthwise_BN/ReadVariableOp/resource
# model/block_7_depthwise_BN/ReadVariableOp
# model/block_7_depthwise_BN/ReadVariableOp_1/resource
# model/block_7_depthwise_BN/ReadVariableOp_1
# model/block_7_depthwise_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_7_depthwise_BN/FusedBatchNormV3/ReadVariableOp
# model/block_7_depthwise_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_7_depthwise_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_7_depthwise_BN/FusedBatchNormV3
# model/block_7_depthwise_relu/Relu6
# model/block_7_project/Conv2D/ReadVariableOp/resource
# model/block_7_project/Conv2D/ReadVariableOp
# model/block_7_project/Conv2D
# model/block_7_project_BN/ReadVariableOp/resource
# model/block_7_project_BN/ReadVariableOp
# model/block_7_project_BN/ReadVariableOp_1/resource
# model/block_7_project_BN/ReadVariableOp_1
# model/block_7_project_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_7_project_BN/FusedBatchNormV3/ReadVariableOp
# model/block_7_project_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_7_project_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_7_project_BN/FusedBatchNormV3
# model/block_7_add/add
# model/block_8_expand/Conv2D/ReadVariableOp/resource
# model/block_8_expand/Conv2D/ReadVariableOp
# model/block_8_expand/Conv2D
# model/block_8_expand_BN/ReadVariableOp/resource
# model/block_8_expand_BN/ReadVariableOp
# model/block_8_expand_BN/ReadVariableOp_1/resource
# model/block_8_expand_BN/ReadVariableOp_1
# model/block_8_expand_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_8_expand_BN/FusedBatchNormV3/ReadVariableOp
# model/block_8_expand_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_8_expand_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_8_expand_BN/FusedBatchNormV3
# model/block_8_expand_relu/Relu6
# model/block_8_depthwise/depthwise/ReadVariableOp/resource
# model/block_8_depthwise/depthwise/ReadVariableOp
# model/block_8_depthwise/depthwise
# model/block_8_depthwise_BN/ReadVariableOp/resource
# model/block_8_depthwise_BN/ReadVariableOp
# model/block_8_depthwise_BN/ReadVariableOp_1/resource
# model/block_8_depthwise_BN/ReadVariableOp_1
# model/block_8_depthwise_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_8_depthwise_BN/FusedBatchNormV3/ReadVariableOp
# model/block_8_depthwise_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_8_depthwise_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_8_depthwise_BN/FusedBatchNormV3
# model/block_8_depthwise_relu/Relu6
# model/block_8_project/Conv2D/ReadVariableOp/resource
# model/block_8_project/Conv2D/ReadVariableOp
# model/block_8_project/Conv2D
# model/block_8_project_BN/ReadVariableOp/resource
# model/block_8_project_BN/ReadVariableOp
# model/block_8_project_BN/ReadVariableOp_1/resource
# model/block_8_project_BN/ReadVariableOp_1
# model/block_8_project_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_8_project_BN/FusedBatchNormV3/ReadVariableOp
# model/block_8_project_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_8_project_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_8_project_BN/FusedBatchNormV3
# model/block_8_add/add
# model/block_9_expand/Conv2D/ReadVariableOp/resource
# model/block_9_expand/Conv2D/ReadVariableOp
# model/block_9_expand/Conv2D
# model/block_9_expand_BN/ReadVariableOp/resource
# model/block_9_expand_BN/ReadVariableOp
# model/block_9_expand_BN/ReadVariableOp_1/resource
# model/block_9_expand_BN/ReadVariableOp_1
# model/block_9_expand_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_9_expand_BN/FusedBatchNormV3/ReadVariableOp
# model/block_9_expand_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_9_expand_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_9_expand_BN/FusedBatchNormV3
# model/block_9_expand_relu/Relu6
# model/block_9_depthwise/depthwise/ReadVariableOp/resource
# model/block_9_depthwise/depthwise/ReadVariableOp
# model/block_9_depthwise/depthwise
# model/block_9_depthwise_BN/ReadVariableOp/resource
# model/block_9_depthwise_BN/ReadVariableOp
# model/block_9_depthwise_BN/ReadVariableOp_1/resource
# model/block_9_depthwise_BN/ReadVariableOp_1
# model/block_9_depthwise_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_9_depthwise_BN/FusedBatchNormV3/ReadVariableOp
# model/block_9_depthwise_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_9_depthwise_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_9_depthwise_BN/FusedBatchNormV3
# model/block_9_depthwise_relu/Relu6
# model/block_9_project/Conv2D/ReadVariableOp/resource
# model/block_9_project/Conv2D/ReadVariableOp
# model/block_9_project/Conv2D
# model/block_9_project_BN/ReadVariableOp/resource
# model/block_9_project_BN/ReadVariableOp
# model/block_9_project_BN/ReadVariableOp_1/resource
# model/block_9_project_BN/ReadVariableOp_1
# model/block_9_project_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_9_project_BN/FusedBatchNormV3/ReadVariableOp
# model/block_9_project_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_9_project_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_9_project_BN/FusedBatchNormV3
# model/block_9_add/add
# model/block_10_expand/Conv2D/ReadVariableOp/resource
# model/block_10_expand/Conv2D/ReadVariableOp
# model/block_10_expand/Conv2D
# model/block_10_expand_BN/ReadVariableOp/resource
# model/block_10_expand_BN/ReadVariableOp
# model/block_10_expand_BN/ReadVariableOp_1/resource
# model/block_10_expand_BN/ReadVariableOp_1
# model/block_10_expand_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_10_expand_BN/FusedBatchNormV3/ReadVariableOp
# model/block_10_expand_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_10_expand_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_10_expand_BN/FusedBatchNormV3
# model/block_10_expand_relu/Relu6
# model/block_10_depthwise/depthwise/ReadVariableOp/resource
# model/block_10_depthwise/depthwise/ReadVariableOp
# model/block_10_depthwise/depthwise
# model/block_10_depthwise_BN/ReadVariableOp/resource
# model/block_10_depthwise_BN/ReadVariableOp
# model/block_10_depthwise_BN/ReadVariableOp_1/resource
# model/block_10_depthwise_BN/ReadVariableOp_1
# model/block_10_depthwise_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_10_depthwise_BN/FusedBatchNormV3/ReadVariableOp
# model/block_10_depthwise_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_10_depthwise_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_10_depthwise_BN/FusedBatchNormV3
# model/block_10_depthwise_relu/Relu6
# model/block_10_project/Conv2D/ReadVariableOp/resource
# model/block_10_project/Conv2D/ReadVariableOp
# model/block_10_project/Conv2D
# model/block_10_project_BN/ReadVariableOp/resource
# model/block_10_project_BN/ReadVariableOp
# model/block_10_project_BN/ReadVariableOp_1/resource
# model/block_10_project_BN/ReadVariableOp_1
# model/block_10_project_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_10_project_BN/FusedBatchNormV3/ReadVariableOp
# model/block_10_project_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_10_project_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_10_project_BN/FusedBatchNormV3
# model/block_11_expand/Conv2D/ReadVariableOp/resource
# model/block_11_expand/Conv2D/ReadVariableOp
# model/block_11_expand/Conv2D
# model/block_11_expand_BN/ReadVariableOp/resource
# model/block_11_expand_BN/ReadVariableOp
# model/block_11_expand_BN/ReadVariableOp_1/resource
# model/block_11_expand_BN/ReadVariableOp_1
# model/block_11_expand_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_11_expand_BN/FusedBatchNormV3/ReadVariableOp
# model/block_11_expand_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_11_expand_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_11_expand_BN/FusedBatchNormV3
# model/block_11_expand_relu/Relu6
# model/block_11_depthwise/depthwise/ReadVariableOp/resource
# model/block_11_depthwise/depthwise/ReadVariableOp
# model/block_11_depthwise/depthwise
# model/block_11_depthwise_BN/ReadVariableOp/resource
# model/block_11_depthwise_BN/ReadVariableOp
# model/block_11_depthwise_BN/ReadVariableOp_1/resource
# model/block_11_depthwise_BN/ReadVariableOp_1
# model/block_11_depthwise_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_11_depthwise_BN/FusedBatchNormV3/ReadVariableOp
# model/block_11_depthwise_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_11_depthwise_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_11_depthwise_BN/FusedBatchNormV3
# model/block_11_depthwise_relu/Relu6
# model/block_11_project/Conv2D/ReadVariableOp/resource
# model/block_11_project/Conv2D/ReadVariableOp
# model/block_11_project/Conv2D
# model/block_11_project_BN/ReadVariableOp/resource
# model/block_11_project_BN/ReadVariableOp
# model/block_11_project_BN/ReadVariableOp_1/resource
# model/block_11_project_BN/ReadVariableOp_1
# model/block_11_project_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_11_project_BN/FusedBatchNormV3/ReadVariableOp
# model/block_11_project_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_11_project_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_11_project_BN/FusedBatchNormV3
# model/block_11_add/add
# model/block_12_expand/Conv2D/ReadVariableOp/resource
# model/block_12_expand/Conv2D/ReadVariableOp
# model/block_12_expand/Conv2D
# model/block_12_expand_BN/ReadVariableOp/resource
# model/block_12_expand_BN/ReadVariableOp
# model/block_12_expand_BN/ReadVariableOp_1/resource
# model/block_12_expand_BN/ReadVariableOp_1
# model/block_12_expand_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_12_expand_BN/FusedBatchNormV3/ReadVariableOp
# model/block_12_expand_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_12_expand_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_12_expand_BN/FusedBatchNormV3
# model/block_12_expand_relu/Relu6
# model/block_12_depthwise/depthwise/ReadVariableOp/resource
# model/block_12_depthwise/depthwise/ReadVariableOp
# model/block_12_depthwise/depthwise
# model/block_12_depthwise_BN/ReadVariableOp/resource
# model/block_12_depthwise_BN/ReadVariableOp
# model/block_12_depthwise_BN/ReadVariableOp_1/resource
# model/block_12_depthwise_BN/ReadVariableOp_1
# model/block_12_depthwise_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_12_depthwise_BN/FusedBatchNormV3/ReadVariableOp
# model/block_12_depthwise_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_12_depthwise_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_12_depthwise_BN/FusedBatchNormV3
# model/block_12_depthwise_relu/Relu6
# model/block_12_project/Conv2D/ReadVariableOp/resource
# model/block_12_project/Conv2D/ReadVariableOp
# model/block_12_project/Conv2D
# model/block_12_project_BN/ReadVariableOp/resource
# model/block_12_project_BN/ReadVariableOp
# model/block_12_project_BN/ReadVariableOp_1/resource
# model/block_12_project_BN/ReadVariableOp_1
# model/block_12_project_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_12_project_BN/FusedBatchNormV3/ReadVariableOp
# model/block_12_project_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_12_project_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_12_project_BN/FusedBatchNormV3
# model/block_12_add/add
# model/block_13_expand/Conv2D/ReadVariableOp/resource
# model/block_13_expand/Conv2D/ReadVariableOp
# model/block_13_expand/Conv2D
# model/block_13_expand_BN/ReadVariableOp/resource
# model/block_13_expand_BN/ReadVariableOp
# model/block_13_expand_BN/ReadVariableOp_1/resource
# model/block_13_expand_BN/ReadVariableOp_1
# model/block_13_expand_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_13_expand_BN/FusedBatchNormV3/ReadVariableOp
# model/block_13_expand_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_13_expand_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_13_expand_BN/FusedBatchNormV3
# model/block_13_expand_relu/Relu6
# model/block_13_pad/Pad/paddings
# model/block_13_pad/Pad
# model/block_13_depthwise/depthwise/ReadVariableOp/resource
# model/block_13_depthwise/depthwise/ReadVariableOp
# model/block_13_depthwise/depthwise
# model/block_13_depthwise_BN/ReadVariableOp/resource
# model/block_13_depthwise_BN/ReadVariableOp
# model/block_13_depthwise_BN/ReadVariableOp_1/resource
# model/block_13_depthwise_BN/ReadVariableOp_1
# model/block_13_depthwise_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_13_depthwise_BN/FusedBatchNormV3/ReadVariableOp
# model/block_13_depthwise_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_13_depthwise_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_13_depthwise_BN/FusedBatchNormV3
# model/block_13_depthwise_relu/Relu6
# model/block_13_project/Conv2D/ReadVariableOp/resource
# model/block_13_project/Conv2D/ReadVariableOp
# model/block_13_project/Conv2D
# model/block_13_project_BN/ReadVariableOp/resource
# model/block_13_project_BN/ReadVariableOp
# model/block_13_project_BN/ReadVariableOp_1/resource
# model/block_13_project_BN/ReadVariableOp_1
# model/block_13_project_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_13_project_BN/FusedBatchNormV3/ReadVariableOp
# model/block_13_project_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_13_project_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_13_project_BN/FusedBatchNormV3
# model/block_14_expand/Conv2D/ReadVariableOp/resource
# model/block_14_expand/Conv2D/ReadVariableOp
# model/block_14_expand/Conv2D
# model/block_14_expand_BN/ReadVariableOp/resource
# model/block_14_expand_BN/ReadVariableOp
# model/block_14_expand_BN/ReadVariableOp_1/resource
# model/block_14_expand_BN/ReadVariableOp_1
# model/block_14_expand_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_14_expand_BN/FusedBatchNormV3/ReadVariableOp
# model/block_14_expand_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_14_expand_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_14_expand_BN/FusedBatchNormV3
# model/block_14_expand_relu/Relu6
# model/block_14_depthwise/depthwise/ReadVariableOp/resource
# model/block_14_depthwise/depthwise/ReadVariableOp
# model/block_14_depthwise/depthwise
# model/block_14_depthwise_BN/ReadVariableOp/resource
# model/block_14_depthwise_BN/ReadVariableOp
# model/block_14_depthwise_BN/ReadVariableOp_1/resource
# model/block_14_depthwise_BN/ReadVariableOp_1
# model/block_14_depthwise_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_14_depthwise_BN/FusedBatchNormV3/ReadVariableOp
# model/block_14_depthwise_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_14_depthwise_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_14_depthwise_BN/FusedBatchNormV3
# model/block_14_depthwise_relu/Relu6
# model/block_14_project/Conv2D/ReadVariableOp/resource
# model/block_14_project/Conv2D/ReadVariableOp
# model/block_14_project/Conv2D
# model/block_14_project_BN/ReadVariableOp/resource
# model/block_14_project_BN/ReadVariableOp
# model/block_14_project_BN/ReadVariableOp_1/resource
# model/block_14_project_BN/ReadVariableOp_1
# model/block_14_project_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_14_project_BN/FusedBatchNormV3/ReadVariableOp
# model/block_14_project_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_14_project_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_14_project_BN/FusedBatchNormV3
# model/block_14_add/add
# model/block_15_expand/Conv2D/ReadVariableOp/resource
# model/block_15_expand/Conv2D/ReadVariableOp
# model/block_15_expand/Conv2D
# model/block_15_expand_BN/ReadVariableOp/resource
# model/block_15_expand_BN/ReadVariableOp
# model/block_15_expand_BN/ReadVariableOp_1/resource
# model/block_15_expand_BN/ReadVariableOp_1
# model/block_15_expand_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_15_expand_BN/FusedBatchNormV3/ReadVariableOp
# model/block_15_expand_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_15_expand_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_15_expand_BN/FusedBatchNormV3
# model/block_15_expand_relu/Relu6
# model/block_15_depthwise/depthwise/ReadVariableOp/resource
# model/block_15_depthwise/depthwise/ReadVariableOp
# model/block_15_depthwise/depthwise
# model/block_15_depthwise_BN/ReadVariableOp/resource
# model/block_15_depthwise_BN/ReadVariableOp
# model/block_15_depthwise_BN/ReadVariableOp_1/resource
# model/block_15_depthwise_BN/ReadVariableOp_1
# model/block_15_depthwise_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_15_depthwise_BN/FusedBatchNormV3/ReadVariableOp
# model/block_15_depthwise_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_15_depthwise_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_15_depthwise_BN/FusedBatchNormV3
# model/block_15_depthwise_relu/Relu6
# model/block_15_project/Conv2D/ReadVariableOp/resource
# model/block_15_project/Conv2D/ReadVariableOp
# model/block_15_project/Conv2D
# model/block_15_project_BN/ReadVariableOp/resource
# model/block_15_project_BN/ReadVariableOp
# model/block_15_project_BN/ReadVariableOp_1/resource
# model/block_15_project_BN/ReadVariableOp_1
# model/block_15_project_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_15_project_BN/FusedBatchNormV3/ReadVariableOp
# model/block_15_project_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_15_project_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_15_project_BN/FusedBatchNormV3
# model/block_15_add/add
# model/block_16_expand/Conv2D/ReadVariableOp/resource
# model/block_16_expand/Conv2D/ReadVariableOp
# model/block_16_expand/Conv2D
# model/block_16_expand_BN/ReadVariableOp/resource
# model/block_16_expand_BN/ReadVariableOp
# model/block_16_expand_BN/ReadVariableOp_1/resource
# model/block_16_expand_BN/ReadVariableOp_1
# model/block_16_expand_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_16_expand_BN/FusedBatchNormV3/ReadVariableOp
# model/block_16_expand_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_16_expand_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_16_expand_BN/FusedBatchNormV3
# model/block_16_expand_relu/Relu6
# model/block_16_depthwise/depthwise/ReadVariableOp/resource
# model/block_16_depthwise/depthwise/ReadVariableOp
# model/block_16_depthwise/depthwise
# model/block_16_depthwise_BN/ReadVariableOp/resource
# model/block_16_depthwise_BN/ReadVariableOp
# model/block_16_depthwise_BN/ReadVariableOp_1/resource
# model/block_16_depthwise_BN/ReadVariableOp_1
# model/block_16_depthwise_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_16_depthwise_BN/FusedBatchNormV3/ReadVariableOp
# model/block_16_depthwise_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_16_depthwise_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_16_depthwise_BN/FusedBatchNormV3
# model/block_16_depthwise_relu/Relu6
# model/block_16_project/Conv2D/ReadVariableOp/resource
# model/block_16_project/Conv2D/ReadVariableOp
# model/block_16_project/Conv2D
# model/block_16_project_BN/ReadVariableOp/resource
# model/block_16_project_BN/ReadVariableOp
# model/block_16_project_BN/ReadVariableOp_1/resource
# model/block_16_project_BN/ReadVariableOp_1
# model/block_16_project_BN/FusedBatchNormV3/ReadVariableOp/resource
# model/block_16_project_BN/FusedBatchNormV3/ReadVariableOp
# model/block_16_project_BN/FusedBatchNormV3/ReadVariableOp_1/resource
# model/block_16_project_BN/FusedBatchNormV3/ReadVariableOp_1
# model/block_16_project_BN/FusedBatchNormV3
# model/Conv_1/Conv2D/ReadVariableOp/resource
# model/Conv_1/Conv2D/ReadVariableOp
# model/Conv_1/Conv2D
# model/Conv_1_bn/ReadVariableOp/resource
# model/Conv_1_bn/ReadVariableOp
# model/Conv_1_bn/ReadVariableOp_1/resource
# model/Conv_1_bn/ReadVariableOp_1
# model/Conv_1_bn/FusedBatchNormV3/ReadVariableOp/resource
# model/Conv_1_bn/FusedBatchNormV3/ReadVariableOp
# model/Conv_1_bn/FusedBatchNormV3/ReadVariableOp_1/resource
# model/Conv_1_bn/FusedBatchNormV3/ReadVariableOp_1
# model/Conv_1_bn/FusedBatchNormV3
# model/out_relu/Relu6
# model/average_pooling2d/AvgPool
# model/flatten/Const
# model/flatten/Reshape
# model/dense/MatMul/ReadVariableOp/resource
# model/dense/MatMul/ReadVariableOp
# model/dense/MatMul
# model/dense/BiasAdd/ReadVariableOp/resource
# model/dense/BiasAdd/ReadVariableOp
# model/dense/BiasAdd
# model/dense/Relu
# model/dropout/Identity
# model/dense_1/MatMul/ReadVariableOp/resource
# model/dense_1/MatMul/ReadVariableOp
# model/dense_1/MatMul
# model/dense_1/BiasAdd/ReadVariableOp/resource
# model/dense_1/BiasAdd/ReadVariableOp
# model/dense_1/BiasAdd
# model/dense_1/Sigmoid
# NoOp
# Identity
# --------------------------------------------------
# Frozen model inputs:
# [<tf.Tensor 'yourInputName:0' shape=(None, 224, 224, 3) dtype=float32>]
# Frozen model outputs:
# [<tf.Tensor 'Identity:0' shape=(None, 2) dtype=float32>]
# '../frozen_models/frozen_graph.pb'

# %%
pb_file = '../frozen_models/frozen_graph.pb'
graph_def = tf.compat.v1.GraphDef()

try:
    with tf.io.gfile.GFile(pb_file, 'rb') as f:
        graph_def.ParseFromString(f.read())
except:
    with tf.gfile.FastGFile(pb_file, 'rb') as f:
        graph_def.ParseFromString(f.read())

# Delete weights
for i in reversed(range(len(graph_def.node))):
    if graph_def.node[i].op == 'Const':
        del graph_def.node[i]

graph_def.library.Clear()

tf.compat.v1.train.write_graph(graph_def, "../frozen_models", 'model.pbtxt', as_text=True)
# Out:
# '../frozen_models/model.pbtxt'

# %%
import cv2
import numpy as np
# Load a model imported from Tensorflow
tensorflowNet = cv2.dnn.readNetFromTensorflow('../frozen_models/frozen_graph.pb', '../frozen_models/model.pbtxt')
# Input image
img = cv2.imread('../../assets/test_photos/10.jpg', cv2.IMREAD_COLOR)
print(img.shape)
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) #(224,224, 3) = (224,224, 1)
img = cv2.cvtColor(img, cv2.COLOR_GRAY2BGR) #(224,224,1) = (224,224,3)
print(img.shape)
image = img.astype(np.float32)
rows, cols, channels = img.shape

mean = np.array([1.0, 1.0, 1.0]) * 127.5
scale = 1 / 127.5

# Use the given image as input, which needs to be blob(s).
blob = cv2.dnn.blobFromImage(image, scale, size=(224, 224), mean=mean, swapRB=True, crop=False)
tensorflowNet.setInput(blob)

# Runs a forward pass to compute the net output
networkOutput = tensorflowNet.forward()[0]
print("Non-mask: ", networkOutput[1])
print("Mask: ", networkOutput[0])
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.grid(None)

# cv2.imshow('Image', img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
# Out:
# (183, 275, 3)
# (183, 275, 3)
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipykernel_6015/1223114198.py in <module>
#      20
#      21 # Runs a forward pass to compute the net output
# ---> 22 networkOutput = tensorflowNet.forward()[0]
#      23 print("Non-mask: ", networkOutput[1])
#      24 print("Mask: ", networkOutput[0])
#
# error: OpenCV(4.5.4-dev) /tmp/pip-req-build-6qnmwb6g/opencv/modules/dnn/src/dnn.cpp:615: error: (-2:Unspecified error) Can't create layer "NoOp" of type "NoOp" in function 'getLayerInstance'
